# %%
import pandas as pd
import numpy as np
from math import sin, cos, sqrt, atan2, radians, asin
import numpy as np

# %%
df = pd.read_excel("hn_real_estate_23.xlsx")
df
# Out:
#              Date  Road_width   Area Direction            Price  \
# 0      11/09/2023        10.0   55.0         _           20 tỷ
# 1      11/09/2023         3.0  100.0         _        10,48 tỷ
# 2      11/09/2023        13.0   80.0  Đông Nam  68 triệu / m2
# 3      11/09/2023         3.0   53.0         _        2,999 tỷ
# 4      11/09/2023         2.5   45.0         _         2,35 tỷ
# ...           ...         ...    ...       ...              ...
# 19156  28/09/2023         4.0  174.0  Đông Nam           15 tỷ
# 19157  28/09/2023        20.0   76.0      Đông         3,45 tỷ
# 19158  27/09/2023         6.0  142.0         _         12,8 tỷ
# 19159  27/09/2023         3.0   74.0         _         2,05 tỷ
# 19160  27/09/2023         4.0   64.0       Bắc         1,15 tỷ
#
#                                                 Location  Length  Width  \
# 0      Phố Doãn Kế Thiện, Phường Mai Dịch, Quận Cầu G...     8.0    7.0
# 1      Phố Tô Vĩnh Diện, Phường Khương Trung, Quận Th...    20.0    5.0
# 2      Đường Đông Hội, Xã Mai Lâm, Huyện Đông Anh, Hà...    16.0    5.0
# 3      Tỉnh Lộ 422B, Xã Vân Canh, Huyện Hoài Đức, Hà Nội    14.0    3.8
# 4      Đường Phương Canh, Phường Phương Canh, Quận Na...    10.0    4.5
# ...                                                  ...     ...    ...
# 19156  Đường Trần Cung, Phường Cổ Nhuế 1, Quận Bắc Từ...     NaN    NaN
# 19157  Đường Tỉnh lộ 419, Xã Đại Yên, Huyện Chương Mỹ...    16.0    5.0
# 19158  Đường Cổ Linh, Phường Thạch Bàn, Quận Long Biê...     NaN    NaN
# 19159  Đường Vân Trì, Xã Vân Nội, Huyện Đông Anh, Hà Nội     NaN    NaN
# 19160  Đường Tỉnh lộ 419, Xã Đại Yên, Huyện Chương Mỹ...    16.0    4.0
#
#        Price (Billions vnd)  Price (Millions vnd/m2)   Latitude   Longitude
# 0                    20.000               363.636364  21.041473  105.777187
# 1                    10.480               104.800000  20.999694  105.820924
# 2                     5.440                68.000000  21.087629  105.866710
# 3                     2.999                56.584906  21.039059  105.727081
# 4                     2.350                52.222222  21.034638  105.746442
# ...                     ...                      ...        ...         ...
# 19156                15.000                86.206897        NaN         NaN
# 19157                 3.450                45.394737        NaN         NaN
# 19158                12.800                90.140845        NaN         NaN
# 19159                 2.050                27.702703        NaN         NaN
# 19160                 1.150                17.968750        NaN         NaN
#
# [19161 rows x 12 columns]

# %%
def haversine(lat1, lon1, lat2, lon2):
    """
    Calculate the great circle distance in kilometers between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371
    return c * r

# %%
df["Distance from center(km)"] = df.apply(lambda row: haversine(row['Latitude'], row['Longitude'], 21.027671, 105.834168), axis=1)
df
# Out:
#              Date  Road_width   Area Direction            Price  \
# 0      11/09/2023        10.0   55.0         _           20 tỷ
# 1      11/09/2023         3.0  100.0         _        10,48 tỷ
# 2      11/09/2023        13.0   80.0  Đông Nam  68 triệu / m2
# 3      11/09/2023         3.0   53.0         _        2,999 tỷ
# 4      11/09/2023         2.5   45.0         _         2,35 tỷ
# ...           ...         ...    ...       ...              ...
# 19156  28/09/2023         4.0  174.0  Đông Nam           15 tỷ
# 19157  28/09/2023        20.0   76.0      Đông         3,45 tỷ
# 19158  27/09/2023         6.0  142.0         _         12,8 tỷ
# 19159  27/09/2023         3.0   74.0         _         2,05 tỷ
# 19160  27/09/2023         4.0   64.0       Bắc         1,15 tỷ
#
#                                                 Location  Length  Width  \
# 0      Phố Doãn Kế Thiện, Phường Mai Dịch, Quận Cầu G...     8.0    7.0
# 1      Phố Tô Vĩnh Diện, Phường Khương Trung, Quận Th...    20.0    5.0
# 2      Đường Đông Hội, Xã Mai Lâm, Huyện Đông Anh, Hà...    16.0    5.0
# 3      Tỉnh Lộ 422B, Xã Vân Canh, Huyện Hoài Đức, Hà Nội    14.0    3.8
# 4      Đường Phương Canh, Phường Phương Canh, Quận Na...    10.0    4.5
# ...                                                  ...     ...    ...
# 19156  Đường Trần Cung, Phường Cổ Nhuế 1, Quận Bắc Từ...     NaN    NaN
# 19157  Đường Tỉnh lộ 419, Xã Đại Yên, Huyện Chương Mỹ...    16.0    5.0
# 19158  Đường Cổ Linh, Phường Thạch Bàn, Quận Long Biê...     NaN    NaN
# 19159  Đường Vân Trì, Xã Vân Nội, Huyện Đông Anh, Hà Nội     NaN    NaN
# 19160  Đường Tỉnh lộ 419, Xã Đại Yên, Huyện Chương Mỹ...    16.0    4.0
#
#        Price (Billions vnd)  Price (Millions vnd/m2)   Latitude   Longitude  \
# 0                    20.000               363.636364  21.041473  105.777187
# 1                    10.480               104.800000  20.999694  105.820924
# 2                     5.440                68.000000  21.087629  105.866710
# 3                     2.999                56.584906  21.039059  105.727081
# 4                     2.350                52.222222  21.034638  105.746442
# ...                     ...                      ...        ...         ...
# 19156                15.000                86.206897        NaN         NaN
# 19157                 3.450                45.394737        NaN         NaN
# 19158                12.800                90.140845        NaN         NaN
# 19159                 2.050                27.702703        NaN         NaN
# 19160                 1.150                17.968750        NaN         NaN
#
#        Distance from center(km)
# 0                      6.109718
# 1                      3.401097
# 2                      7.473472
# 3                     11.185999
# 4                      9.137821
# ...                         ...
# 19156                       NaN
# 19157                       NaN
# 19158                       NaN
# 19159                       NaN
# 19160                       NaN
#
# [19161 rows x 13 columns]
